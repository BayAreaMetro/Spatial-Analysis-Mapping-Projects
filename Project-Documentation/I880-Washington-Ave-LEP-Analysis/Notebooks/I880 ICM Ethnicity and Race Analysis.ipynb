# %%
import os
import sys
import getpass
import requests
import numpy as np
import pandas as pd
import geopandas as gpd

user = getpass.getuser()
sys.dont_write_bytecode = True

# sys.path.insert(0, '/Users/{}/Box/Utility Code'.format(user))

# for macOS Monterey
sys.path.insert(0, '/Users/{}/Library/CloudStorage/Box-Box/Utility Code'.format(user))

import utils_io as utils

# for macOS Monterey
sys.path.insert(0, '/Users/{}/Documents/GitHub/hess_application/data_processing/6 - affh'.format(user))

import census

# %% [markdown]
# ## Pull Decennial Census table variables and export as csv

# %%
census_key = getpass.getpass()
# Out:
# ········

# %%
# pull decennial census table variables from api
rq = requests.get('https://api.census.gov/data/2020/dec/pl/variables.json')
data = rq.json()

# %%
# create dataframe from dictionary
tbl_vars = pd.DataFrame.from_dict(data['variables'], orient='index')

# %%
# reset index
tbl_vars.reset_index(inplace=True)

# %%
# rename index column set as name (for variable name)
tbl_vars.rename(columns={'index':'name'}, inplace=True)

# %%
# filter variables to only include 
p2_vars = [
    'P2_001N',
    'P2_002N',
    'P2_003N',
    'P2_004N',
    'P2_005N',
    'P2_006N',
    'P2_007N',
    'P2_008N',
    'P2_009N',
    'P2_010N',
    'P2_011N'
]
p2_race_vars = tbl_vars[tbl_vars['name'].isin(p2_vars)]

# %%
p2_race_vars.sort_values(by='name').to_csv('../Data/decennial_census_tbl_vars_p2.csv')

# %% [markdown]
# ## Pull Decennial Census data from Census API

# %%
# create list of census variables to provide as a param in next step
dc_vars_lst = p2_race_vars['name'].to_list()

# %%
# pull census data
dc_df = census.pull_decennial_census_data(census_api_key=census_key, select_table_vars=dc_vars_lst)

# %%
rename_dict = {
    'P2_001N': 'total_pop',
    'P2_002N': 'hispanic_latino_pop',
    'P2_003N': 'non_hispanic_latino_pop',
    'P2_004N': 'non_hl_pop_one_race',
    'P2_005N': 'non_hl_white',
    'P2_006N': 'non_hl_black',
    'P2_007N': 'non_hl_indian_alaska_native',
    'P2_008N': 'non_hl_asian',
    'P2_009N': 'non_hl_hawaiian_pacific_islander',
    'P2_010N': 'non_hl_other_race',
    'P2_011N': 'non_hl_multi_racial'
}
dc_df.rename(columns=rename_dict, inplace=True)

# %%
col_order = [
    'fipco',
    'tract_geoid',
    'total_pop',
    'hispanic_latino_pop',
    'non_hl_white',
    'non_hl_black',
    'non_hl_indian_alaska_native',
    'non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'non_hl_multi_racial'
]
dc_df = dc_df[col_order].copy()

# %% [markdown]
# ## Create share columns
#
# Create columns which represent an estimate of a given race as a share of the universe which is the total population of a Census tract.

# %%
pop_cols = [
    'hispanic_latino_pop',
    'non_hl_white',
    'non_hl_black',
    'non_hl_indian_alaska_native',
    'non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'non_hl_multi_racial'
]

# %%
# Initialize dictionary with population column names and blank values
{key: 'pct_' + key for key in pop_cols}
# Out:
# {'hispanic_latino_pop': 'pct_hispanic_latino_pop',
#  'non_hl_white': 'pct_non_hl_white',
#  'non_hl_black': 'pct_non_hl_black',
#  'non_hl_indian_alaska_native': 'pct_non_hl_indian_alaska_native',
#  'non_hl_asian': 'pct_non_hl_asian',
#  'non_hl_hawaiian_pacific_islander': 'pct_non_hl_hawaiian_pacific_islander',
#  'non_hl_other_race': 'pct_non_hl_other_race',
#  'non_hl_multi_racial': 'pct_non_hl_multi_racial'}

# %%
dc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1772 entries, 0 to 1771
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   fipco                             1772 non-null   object
#  1   tract_geoid                       1772 non-null   object
#  2   total_pop                         1772 non-null   int64
#  3   hispanic_latino_pop               1772 non-null   int64
#  4   non_hl_white                      1772 non-null   int64
#  5   non_hl_black                      1772 non-null   int64
#  6   non_hl_indian_alaska_native       1772 non-null   int64
#  7   non_hl_asian                      1772 non-null   int64
#  8   non_hl_hawaiian_pacific_islander  1772 non-null   int64
#  9   non_hl_other_race                 1772 non-null   int64
#  10  non_hl_multi_racial               1772 non-null   int64
# dtypes: int64(9), object(2)
# memory usage: 152.4+ KB

# %%
pop_share_dict = {
    'hispanic_latino_pop': 'pct_hispanic_latino_pop',
    'non_hl_white': 'pct_non_hl_white',
    'non_hl_black': 'pct_non_hl_black',
    'non_hl_indian_alaska_native': 'pct_non_hl_indian_alaska_native',
    'non_hl_asian': 'pct_non_hl_asian',
    'non_hl_hawaiian_pacific_islander': 'pct_non_hl_hawaiian_pacific_islander',
    'non_hl_other_race': 'pct_non_hl_other_race',
    'non_hl_multi_racial': 'pct_non_hl_multi_racial'
}
# create share columns
dc_df = census.create_share_columns(df=dc_df, 
                                    universe_column='total_pop', 
                                    share_column_dict=pop_share_dict
                                   )

# %% [markdown]
# ## Join tract attributes to geodata

# %%
tracts_gdf = census.pull_census_tracts_geodata(year=2020, cartographic=True)

# %%
tracts_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5bfb6b1e578f33500dd7c697cd63b510 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5bfb6b1e578f33500dd7c697cd63b510&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5bfb6b1e578f33500dd7c697cd63b510 = L.map(
#                 &quot;map_5bfb6b1e578f33500dd7c697cd63b510&quot;,
#                 {
#                     center: [37.87863899973213, -122.37088149996387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5bfb6b1e578f33500dd7c697cd63b510);
#
#
#
#
#
#             var tile_layer_0c14826cbad00a79fae475275e5d1f95 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5bfb6b1e578f33500dd7c697cd63b510);
#
#
#             map_5bfb6b1e578f33500dd7c697cd63b510.fitBounds(
#                 [[36.893032999787735, -123.53353500006253], [38.86424499967652, -121.2082279998652]],
#                 {}
#             );
#
#
#         function geo_json_d3369191dd116ca419edec1e544bf490_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d3369191dd116ca419edec1e544bf490_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d3369191dd116ca419edec1e544bf490_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d3369191dd116ca419edec1e544bf490_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d3369191dd116ca419edec1e544bf490_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d3369191dd116ca419edec1e544bf490.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d3369191dd116ca419edec1e544bf490_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d3369191dd116ca419edec1e544bf490 = L.geoJson(null, {
#                 onEachFeature: geo_json_d3369191dd116ca419edec1e544bf490_onEachFeature,
#
#                 style: geo_json_d3369191dd116ca419edec1e544bf490_styler,
#                 pointToLayer: geo_json_d3369191dd116ca419edec1e544bf490_pointToLayer
#         });
#
#         function geo_json_d3369191dd116ca419edec1e544bf490_add (data) {
#             geo_json_d3369191dd116ca419edec1e544bf490
#                 .addData(data)
#                 .addTo(map_5bfb6b1e578f33500dd7c697cd63b510);
#         }
#             geo_json_d3369191dd116ca419edec1e544bf490_add({&quot;bbox&quot;: [-123.53353500006253, 36.893032999787735, -121.2082279998652, 38.86424499967652], &quot;features&quot;: [{&quot;bbox&quot;: [-122.24691000043892, 37.84996199998922, -122.21237999969411, 37.8853549997613], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.24691000043892, 37.8853549997613], [-122.2468269996999, 37.88407299986024], [-122.2464390002607, 37.88120299980722], [-122.24515600032079, 37.869737000004946], [-122.24460300012683, 37.86739999978123], [-122.24533799989567, 37.86598600029502], [-122.24473299982316, 37.86578800013319], [-122.24552500039171, 37.86403599982632], [-122.24416600028383, 37.86149700003579], [-122.24427400023886, 37.86142700028853], [-122.2442349998808, 37.861065999827424], [-122.2440650000015, 37.860776000164364],

# %%
dc_gdf = pd.merge(tracts_gdf, dc_df, how='inner', on='tract_geoid')

# %% [markdown]
# ## Read Washington Ave corridor geodata & create buffer

# %%
work_dir = os.path.join(
    '/Users',
    user,
    'Library',
    'CloudStorage',
    'Box-Box',
    'DataViz Projects',
    'Spatial Analysis and Mapping',
    'I-880 LEP Analysis'
)

# %%
corridor_gdf = gpd.read_file(os.path.join(work_dir,'Data','i880_icm_washington_ave_corridor.json'))

# %%
corridor_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab3a8355cf555f09917e0a31cf47c0ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab3a8355cf555f09917e0a31cf47c0ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ab3a8355cf555f09917e0a31cf47c0ca = L.map(
#                 &quot;map_ab3a8355cf555f09917e0a31cf47c0ca&quot;,
#                 {
#                     center: [37.705847345543646, -122.12905637952093],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ab3a8355cf555f09917e0a31cf47c0ca);
#
#
#
#
#
#             var tile_layer_2dbc0131738d96b5f5e17abebf86984e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ab3a8355cf555f09917e0a31cf47c0ca);
#
#
#             map_ab3a8355cf555f09917e0a31cf47c0ca.fitBounds(
#                 [[37.68814467981602, -122.15385227455342], [37.723550011271264, -122.10426048448846]],
#                 {}
#             );
#
#
#         function geo_json_a9db598c7e2679b1bafb685963d408b0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a9db598c7e2679b1bafb685963d408b0_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a9db598c7e2679b1bafb685963d408b0_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a9db598c7e2679b1bafb685963d408b0_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a9db598c7e2679b1bafb685963d408b0_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_a9db598c7e2679b1bafb685963d408b0.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a9db598c7e2679b1bafb685963d408b0_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a9db598c7e2679b1bafb685963d408b0 = L.geoJson(null, {
#                 onEachFeature: geo_json_a9db598c7e2679b1bafb685963d408b0_onEachFeature,
#
#                 style: geo_json_a9db598c7e2679b1bafb685963d408b0_styler,
#                 pointToLayer: geo_json_a9db598c7e2679b1bafb685963d408b0_pointToLayer
#         });
#
#         function geo_json_a9db598c7e2679b1bafb685963d408b0_add (data) {
#             geo_json_a9db598c7e2679b1bafb685963d408b0
#                 .addData(data)
#                 .addTo(map_ab3a8355cf555f09917e0a31cf47c0ca);
#         }
#             geo_json_a9db598c7e2679b1bafb685963d408b0_add({&quot;bbox&quot;: [-122.15385227455342, 37.68814467981602, -122.10426048448846, 37.723550011271264], &quot;features&quot;: [{&quot;bbox&quot;: [-122.15385227455342, 37.68814467981602, -122.10426048448846, 37.723550011271264], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-122.15385227455342, 37.723550011271264], [-122.14801567745351, 37.719192981830666], [-122.14269856603268, 37.71528342836451], [-122.13971963132552, 37.713111168424724], [-122.13057352234286, 37.70666176808561], [-122.12494278847318, 37.702846223426256], [-122.12270945785266, 37.70120630016671], [-122.10982617097058, 37.69213287976127], [-122.10426048448846, 37.68814467981602]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;OBJECTID&

# %%
# create a copy of the line gdf
corridor_buff_gdf = corridor_gdf.copy()

# %%
# create 3.5 mile (5632.7 meter) buffer
corridor_buff_gdf['geometry'] = corridor_gdf.geometry.buffer(distance=5632.7)

# %%
# review the results on an interactive map
corridor_buff_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1da303ba84fcf9c78cc70e3d5d48ba50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1da303ba84fcf9c78cc70e3d5d48ba50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1da303ba84fcf9c78cc70e3d5d48ba50 = L.map(
#                 &quot;map_1da303ba84fcf9c78cc70e3d5d48ba50&quot;,
#                 {
#                     center: [37.70586239445603, -122.12909174182343],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1da303ba84fcf9c78cc70e3d5d48ba50);
#
#
#
#
#
#             var tile_layer_e33961de2f1aed43dc9963916c88d2c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1da303ba84fcf9c78cc70e3d5d48ba50);
#
#
#             map_1da303ba84fcf9c78cc70e3d5d48ba50.fitBounds(
#                 [[37.63743356035939, -122.21773244808583], [37.77429122855266, -122.04045103556103]],
#                 {}
#             );
#
#
#         function geo_json_d25e31b4330ee41f0741fb3b6b18ac90_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d25e31b4330ee41f0741fb3b6b18ac90_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d25e31b4330ee41f0741fb3b6b18ac90_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d25e31b4330ee41f0741fb3b6b18ac90_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d25e31b4330ee41f0741fb3b6b18ac90_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d25e31b4330ee41f0741fb3b6b18ac90.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d25e31b4330ee41f0741fb3b6b18ac90_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d25e31b4330ee41f0741fb3b6b18ac90 = L.geoJson(null, {
#                 onEachFeature: geo_json_d25e31b4330ee41f0741fb3b6b18ac90_onEachFeature,
#
#                 style: geo_json_d25e31b4330ee41f0741fb3b6b18ac90_styler,
#                 pointToLayer: geo_json_d25e31b4330ee41f0741fb3b6b18ac90_pointToLayer
#         });
#
#         function geo_json_d25e31b4330ee41f0741fb3b6b18ac90_add (data) {
#             geo_json_d25e31b4330ee41f0741fb3b6b18ac90
#                 .addData(data)
#                 .addTo(map_1da303ba84fcf9c78cc70e3d5d48ba50);
#         }
#             geo_json_d25e31b4330ee41f0741fb3b6b18ac90_add({&quot;bbox&quot;: [-122.21773244808583, 37.63743356035939, -122.04045103556103, 37.77429122855266], &quot;features&quot;: [{&quot;bbox&quot;: [-122.21773244808583, 37.63743356035939, -122.04045103556103, 37.77429122855266], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-122.10440439878609, 37.75630978577308], [-122.09936463536337, 37.75260253751533], [-122.09687921109473, 37.75078937581845], [-122.0886070045084, 37.744953812063336], [-122.08345761156919, 37.741463056455515], [-122.08155584480609, 37.74012084801993], [-122.07981228934194, 37.73884001261268], [-122.0674270487352, 37.73011369597307], [-122.06702432208554, 37.72982746345763], [-122.06145819366859, 37.7258372608371], [-122.05701424480993, 37.722321711567815], [-122.0530259279158, 37.71847696607971

# %% [markdown]
# ## Clip tracts within study area

# %%
corridor_buff_gdf.crs
# Out:
# <Derived Projected CRS: EPSG:26910>
# Name: NAD83 / UTM zone 10N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: North America - between 126°W and 120°W - onshore and offshore. Canada - British Columbia; Northwest Territories; Yukon. United States (USA) - California; Oregon; Washington.
# - bounds: (-126.0, 30.54, -119.99, 81.8)
# Coordinate Operation:
# - name: UTM zone 10N
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# project to same system as corridor data
dc_gdf_epsg26910 = dc_gdf.to_crs('EPSG:26910')

# %%
# perform clip operation
dc_corridor_gdf = gpd.clip(dc_gdf_epsg26910, corridor_buff_gdf)
# Out:
# /Users/jcroff/anaconda3/envs/geo_env/lib/python3.10/site-packages/geopandas/tools/clip.py:66: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
# review results on an interactive map
dc_corridor_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3075f1825324b6debb26285b4e1a2ada {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3075f1825324b6debb26285b4e1a2ada&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3075f1825324b6debb26285b4e1a2ada = L.map(
#                 &quot;map_3075f1825324b6debb26285b4e1a2ada&quot;,
#                 {
#                     center: [37.70586239445603, -122.12909174182343],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3075f1825324b6debb26285b4e1a2ada);
#
#
#
#
#
#             var tile_layer_1afb5b8fbc79adb78fe4c6854e0250d9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3075f1825324b6debb26285b4e1a2ada);
#
#
#             map_3075f1825324b6debb26285b4e1a2ada.fitBounds(
#                 [[37.63743356035939, -122.21773244808583], [37.77429122855266, -122.04045103556103]],
#                 {}
#             );
#
#
#         function geo_json_c2ca0881dd38da7be1e97a069ae86c3f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c2ca0881dd38da7be1e97a069ae86c3f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c2ca0881dd38da7be1e97a069ae86c3f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c2ca0881dd38da7be1e97a069ae86c3f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c2ca0881dd38da7be1e97a069ae86c3f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c2ca0881dd38da7be1e97a069ae86c3f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c2ca0881dd38da7be1e97a069ae86c3f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c2ca0881dd38da7be1e97a069ae86c3f = L.geoJson(null, {
#                 onEachFeature: geo_json_c2ca0881dd38da7be1e97a069ae86c3f_onEachFeature,
#
#                 style: geo_json_c2ca0881dd38da7be1e97a069ae86c3f_styler,
#                 pointToLayer: geo_json_c2ca0881dd38da7be1e97a069ae86c3f_pointToLayer
#         });
#
#         function geo_json_c2ca0881dd38da7be1e97a069ae86c3f_add (data) {
#             geo_json_c2ca0881dd38da7be1e97a069ae86c3f
#                 .addData(data)
#                 .addTo(map_3075f1825324b6debb26285b4e1a2ada);
#         }
#             geo_json_c2ca0881dd38da7be1e97a069ae86c3f_add({&quot;bbox&quot;: [-122.21773244808583, 37.63743356035939, -122.04045103556103, 37.77429122855266], &quot;features&quot;: [{&quot;bbox&quot;: [-122.04727400011556, 37.67444600034703, -122.04045103556103, 37.69868841819693], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-122.0411320002274, 37.68055900030121], [-122.04259000006952, 37.6833119998473], [-122.0437359997421, 37.68671700029249], [-122.04398000013957, 37.68699700018611], [-122.04544200017965, 37.688207999816086], [-122.04576100002186, 37.68847099981602], [-122.0464389998893, 37.68862999975556], [-122.0468769995572, 37.68896799976419], [-122.04715100009193, 37.689666000059404], [-122.04727400011556, 37.690936999928155], [-122.04663399988297, 37.69149300025214], [-122.04603999968111, 37.69203200011539

# %% [markdown]
# ## Export corridor data

# %%
reorder_cols = [
    'fipco',
    'tract_geoid',
    'total_pop',
    'hispanic_latino_pop',
    'pct_hispanic_latino_pop',
    'non_hl_white',
    'pct_non_hl_white',
    'non_hl_black',
    'pct_non_hl_black',
    'non_hl_indian_alaska_native',
    'pct_non_hl_indian_alaska_native',
    'non_hl_asian',
    'pct_non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'pct_non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'pct_non_hl_other_race',
    'non_hl_multi_racial',
    'pct_non_hl_multi_racial',
    'geometry'
]
dc_gdf = dc_gdf[reorder_cols]

# %%
# export geodata
path = os.path.join(work_dir, 'Data', 'Hispanic_Latino_Not_Hispanic_Latino_by_Race_Tracts_dc2020.geojson')
dc_gdf.to_file(path, driver='GeoJSON')

# %%
# Export tabular data
csv_cols = [
    'fipco',
    'tract_geoid',
    'total_pop',
    'hispanic_latino_pop',
    'pct_hispanic_latino_pop',
    'non_hl_white',
    'pct_non_hl_white',
    'non_hl_black',
    'pct_non_hl_black',
    'non_hl_indian_alaska_native',
    'pct_non_hl_indian_alaska_native',
    'non_hl_asian',
    'pct_non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'pct_non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'pct_non_hl_other_race',
    'non_hl_multi_racial',
    'pct_non_hl_multi_racial'
]
path = os.path.join(work_dir, 'Data', 'Hispanic_Latino_Not_Hispanic_Latino_by_Race_Tracts_dc2020.csv')
dc_gdf[csv_cols].to_csv(path, index=False)

# %% [markdown]
# ## Summarize data

# %%
summary_cols = [
    'total_pop',
    'hispanic_latino_pop',
    'non_hl_white',
    'non_hl_black',
    'non_hl_indian_alaska_native',
    'non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'non_hl_multi_racial'
]
study_area_summary = dc_gdf[summary_cols].aggregate('sum').to_frame().T

# %%
study_area_summary
# Out:
#    total_pop  hispanic_latino_pop  non_hl_white  non_hl_black  \
# 0    7765640              1891985       2783589        435009
#
#    non_hl_indian_alaska_native  non_hl_asian  \
# 0                        18254       2150320
#
#    non_hl_hawaiian_pacific_islander  non_hl_other_race  non_hl_multi_racial
# 0                             43214              50035               393234

# %%
# create share columns
study_area_summary = census.create_share_columns(df=study_area_summary, 
                                                 universe_column='total_pop', 
                                                 share_column_dict=pop_share_dict
                                                )

# %%
study_area_summary.columns.to_list()
# Out:
# ['total_pop',
#  'hispanic_latino_pop',
#  'non_hl_white',
#  'non_hl_black',
#  'non_hl_indian_alaska_native',
#  'non_hl_asian',
#  'non_hl_hawaiian_pacific_islander',
#  'non_hl_other_race',
#  'non_hl_multi_racial',
#  'pct_hispanic_latino_pop',
#  'pct_non_hl_white',
#  'pct_non_hl_black',
#  'pct_non_hl_indian_alaska_native',
#  'pct_non_hl_asian',
#  'pct_non_hl_hawaiian_pacific_islander',
#  'pct_non_hl_other_race',
#  'pct_non_hl_multi_racial']

# %%
# reorder summary columns
reorder_cols = [
    'total_pop',
    'hispanic_latino_pop',
    'pct_hispanic_latino_pop',
    'non_hl_white',
    'pct_non_hl_white',
    'non_hl_black',
    'pct_non_hl_black',
    'non_hl_indian_alaska_native',
    'pct_non_hl_indian_alaska_native',
    'non_hl_asian',
    'pct_non_hl_asian',
    'non_hl_hawaiian_pacific_islander',
    'pct_non_hl_hawaiian_pacific_islander',
    'non_hl_other_race',
    'pct_non_hl_other_race',
    'non_hl_multi_racial',
    'pct_non_hl_multi_racial'
]
study_area_summary = study_area_summary[reorder_cols]

# %%
# transpose summary data
study_area_transpose = study_area_summary.T

# %%
# rename index column 
study_area_transpose.rename(columns={0:'Summary_Statistics'}, inplace=True)

# %%
# export summary area data to csv
path = os.path.join(work_dir, 'Data', 'Hispanic_Latino_Not_Hispanic_Latino_by_Race_Summary_Statistics_dc2020.csv')
study_area_transpose.to_csv(path, index=True)
