# %%
import os
import pandas as pd
import fiona
import geopandas as gpd

# %%
match_dir = os.path.join('/Users',
                        'jcroff',
                        'Box',
                        'DataViz Projects',
                        'Spatial Analysis and Mapping',
                        'Active Transportation Plan',
                        'Data',
                        'shst_match_results',
                        'by_data_source_matched')

# %%
toole_dir = os.path.join('/Users',
                        'jcroff',
                        'Box',
                        'MTC Data for Toole Design')

# %%
os.listdir(match_dir)
# Out:
# ['actc_bike_network_epsg4326_matched.geojson',
#  'batc_bike_network_epsg4326_matched.geojson',
#  'caltrans_d4_bike_network_epsg4326_matched.geojson',
#  'ccta_bike_network_epsg4326_matched.geojson',
#  'nvta_bike_network_epsg4326_matched.geojson',
#  'oakland_bike_network_epsg4326_matched.geojson',
#  'scta_bike_network_epsg4326_matched.geojson',
#  'sfcta_bike_network_epsg4326_matched.geojson',
#  'sta_bike_network_epsg4326_matched.geojson',
#  'tam_bike_network_epsg4326_matched.geojson',
#  'vta_bike_network_epsg4326_matched.geojson']

# %%
os.listdir(toole_dir)
# Out:
# ['Bay Area Trails Collaborative Network',
#  'County, City and Caltrans Bike Ped Network and Counts Data',
#  'data_for_Toole.gdb',
#  'GIS Data Request.xlsx',
#  'Local and Regional Transit',
#  'MTC Mobility Hubs top25_final_20210308.html',
#  'MTC_mobility_hubs_R_final.zip',
#  'PBA50_FinalBlueprintLandUse_TAZdata_dataDictionary.xlsx',
#  'travelModel2_v11_link_csv.csv',
#  'travelModel2_v11_link_json.zip']

# %%
fiona.listlayers(os.path.join(toole_dir,'data_for_Toole.gdb'))
# Out:
# ['census_2002_2018_lehd_by_block',
#  'regional_bikeway_network_2019',
#  'tomtom_cityLimits_region',
#  'tomtom_cityLimits_region_clipped',
#  'tomtom_countyBoundaries_region',
#  'tomtom_countyBoundaries_region_clipped',
#  'travelModel2_v11_node',
#  'travelModel2_v11_shape',
#  'BayAreaTrailsCollaborative_TrailNetwork',
#  'equity_priority_communities_2020_acs2018',
#  'priority_development_areas_pba2050',
#  'travelModel2_landUseByTAZ_2015',
#  'travelModel2_landUseByTAZ_2035',
#  'travelModel2_landUseByTAZ_2050',
#  'travelModel2_v11_link']

# %%
tm2_nw_shape = gpd.read_file(os.path.join(toole_dir,'data_for_Toole.gdb'),
                             driver='FileGDB',
                             layer='travelModel2_v11_shape')

# %%
tm2_nw_shape.head(5)
# Out:
#                     backReferenceId                forwardReferenceId  \
# 0  d0e1dddc808772de514b913b8f6875c7  1f25555f0c2f4a6c1205f4f0079c818f
# 1  f38e31579534d3a5abb518ef31bb0517  89dd7cf0f842c091241b9a139a5e9506
# 2  80c4235b61bd0fe1b1538b8b36b40958  31529c3bf7a3c1a1aa9f76a607762487
# 3  5db4d3943495df8be0ec50e54142ba76  a70e2e0a5ae6887d0c7b05ed4697c38b
# 4  adbcce138fec70e8b6c0abbc86918b1c  91739e1e9ab6e5825162731d510ac4cb
#
#                  fromIntersectionId                                id  \
# 0  fc62d018be0236d6b9e43536ebc51830  89d807e34d7630c619bbc23a64e1313e
# 1  1bf4572e933b7f6d81535ff217053926  95451c235af17ca9cde815dfc3f4b6ce
# 2  fc62d018be0236d6b9e43536ebc51830  6c28c78ee3ac710cf40194e2cac3730d
# 3  3e8bf208fb1c0ead020efb50b80c55a2  bcf240fee04a590969705fdaeea814ea
# 4  cc73172a9282f3a8567c5d5303a61b42  2172fcefdf21e39f6810c4deaf9f89ee
#
#    shape_id                  toIntersectionId  Shape_Length  \
# 0       1.0  61c9208c38c5d942c222859cb7073e30      0.001842
# 1       2.0  d60ae663adb14804616d2ca06c3ff8fb      0.000060
# 2       3.0  d60ae663adb14804616d2ca06c3ff8fb      0.001300
# 3       4.0  41a9c2c8d1301064a72cedcb5f063361      0.000810
# 4       5.0  41a9c2c8d1301064a72cedcb5f063361      0.001037
#
#                                             geometry
# 0  MULTILINESTRING Z ((-121.81724 38.00970 0.0000...
# 1  MULTILINESTRING Z ((-121.81720 38.00839 0.0000...
# 2  MULTILINESTRING Z ((-121.81724 38.00970 0.0000...
# 3  MULTILINESTRING Z ((-121.81806 38.00838 0.0000...
# 4  MULTILINESTRING Z ((-121.81878 38.00941 0.0000...

# %%
tm2_link_attr = gpd.read_file(os.path.join(toole_dir,'data_for_Toole.gdb'), 
                                          driver='FileGDB',
                                          layer='travelModel2_v11_link')

# %%
tm2_link_attr.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2199321 entries, 0 to 2199320
# Data columns (total 45 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   access              object
#  1   bike_access         int64
#  2   drive_access        int64
#  3   fromIntersectionId  object
#  4   lanes               object
#  5   maxspeed            object
#  6   name                object
#  7   oneWay              object
#  8   ref                 object
#  9   roadway             object
#  10  shstGeometryId      object
#  11  shstReferenceId     object
#  12  toIntersectionId    object
#  13  u                   float64
#  14  v                   float64
#  15  walk_access         int64
#  16  wayId               object
#  17  county              object
#  18  model_link_id       int64
#  19  A                   int64
#  20  B                   int64
#  21  rail_traveltime     object
#  22  rail_only           int64
#  23  locationReferences  object
#  24  shape_id            float64
#  25  ft_cal              float64
#  26  ft                  int64
#  27  useclass            float64
#  28  assignable_cal      float64
#  29  assignable          int64
#  30  transit             float64
#  31  id                  object
#  32  tollbooth           int64
#  33  bus_only            int64
#  34  transit_access      object
#  35  managed             int64
#  36  ML_lanes            object
#  37  segment_id          int64
#  38  ML_tollbooth        object
#  39  ML_useclass         object
#  40  ML_access           object
#  41  ML_egress           object
#  42  ML_tollseg          object
#  43  tollseg             int64
#  44  geometry            geometry
# dtypes: float64(7), geometry(1), int64(14), object(23)
# memory usage: 755.1+ MB

# %%
tm2_link_attr[['fromIntersectionId','shstGeometryId','shstReferenceId','toIntersectionId','shape_id']].head(5)
# Out:
#                  fromIntersectionId                    shstGeometryId  \
# 0  505d64eb98f1da8d812a3b3801034308  208e093f10a62dcc6646a8efa0bde136
# 1  473979c78435732f01ca5a168afb62e0  5fe3056a5583474c0c898983cd6a638b
# 2  fc7b575d5d8c961d4a70fca846ae7f80  38e962038ecf17c6c7394ba88bc3b4c1
# 3  6c60cf34e9dc3e123eefb829fe80c76a  f3558c6d4c7e3d48742ea3755186c20d
# 4  013e1f994fd86c1f226098f8364f7286  550ef74674d67256659c5ab80d35d7a7
#
#                     shstReferenceId                  toIntersectionId  \
# 0  00000461094d7f302e7afdcfc7ff5ba3  fb8b1bcb4bb81380f0dc83c1aa5006f4
# 1  00000b467d2e08f9abf13eeafee3ed46  5adfc2245bcc082b5b004dbc53d9dfb0
# 2  000018062272093dbaa5d49303062454  7550e87fc64657a10282672d814ab3c5
# 3  000018a23d1330dcfbae79f44e9fca1a  cce854f3462409d6825c15ac6309f495
# 4  0000491ae6975893d350d75ed7aa5842  9513a9ae6406c5d62f9bf1a7bafd2b73
#
#    shape_id
# 0  512475.0
# 1   38201.0
# 2  347066.0
# 3  856377.0
# 4  814428.0

# %% [markdown]
# ## Read geojson into dataframe

# %%
actc = gpd.read_file(os.path.join(match_dir,'actc_bike_network_epsg4326_matched.geojson'),
                     driver='GeoJSON')

# %%
actc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 87856 entries, 0 to 87855
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shstReferenceId     87856 non-null  object
#  1   shstGeometryId      87856 non-null  object
#  2   fromIntersectionId  87856 non-null  object
#  3   toIntersectionId    87856 non-null  object
#  4   pp_id               87856 non-null  int64
#  5   pp_street_nam       87856 non-null  object
#  6   pp_trail_name       87856 non-null  object
#  7   pp_jurisdicti       87856 non-null  object
#  8   pp_existing_f       87856 non-null  object
#  9   pp_planned_fa       87856 non-null  object
#  10  pp_source           87856 non-null  object
#  11  pp_ex_class         54594 non-null  float64
#  12  pp_pln_class        50008 non-null  float64
#  13  pp_shape_length     87856 non-null  float64
#  14  pp_mtc_facility_id  87856 non-null  object
#  15  source              87856 non-null  object
#  16  geometry            87856 non-null  geometry
# dtypes: float64(3), geometry(1), int64(1), object(12)
# memory usage: 11.4+ MB

# %%
actc.rename(columns={'pp_ex_class':'cma_ex_class',
                     'pp_pln_class':'cma_pln_class'},inplace=True)

# %%
actc.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 87856 entries, 0 to 87855
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shstReferenceId     87856 non-null  object
#  1   shstGeometryId      87856 non-null  object
#  2   fromIntersectionId  87856 non-null  object
#  3   toIntersectionId    87856 non-null  object
#  4   pp_id               87856 non-null  int64
#  5   pp_street_nam       87856 non-null  object
#  6   pp_trail_name       87856 non-null  object
#  7   pp_jurisdicti       87856 non-null  object
#  8   pp_existing_f       87856 non-null  object
#  9   pp_planned_fa       87856 non-null  object
#  10  pp_source           87856 non-null  object
#  11  cma_ex_class        54594 non-null  float64
#  12  cma_pln_class       50008 non-null  float64
#  13  pp_shape_length     87856 non-null  float64
#  14  pp_mtc_facility_id  87856 non-null  object
#  15  source              87856 non-null  object
#  16  geometry            87856 non-null  geometry
# dtypes: float64(3), geometry(1), int64(1), object(12)
# memory usage: 11.4+ MB

# %%
oak = gpd.read_file(os.path.join(match_dir,'oakland_bike_network_epsg4326_matched.geojson'),
                    driver='GeoJSON')

# %%
oak.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 11886 entries, 0 to 11885
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shstReferenceId     11886 non-null  object
#  1   shstGeometryId      11886 non-null  object
#  2   fromIntersectionId  11886 non-null  object
#  3   toIntersectionId    11886 non-null  object
#  4   pp_id               11886 non-null  int64
#  5   pp_shape_leng       11886 non-null  float64
#  6   pp_roadway          11886 non-null  object
#  7   pp_beginning        11886 non-null  object
#  8   pp_ending           11886 non-null  object
#  9   pp_proposedcl       11886 non-null  object
#  10  pp_existingcl       11886 non-null  object
#  11  pp_prioritypr       11886 non-null  object
#  12  pp_vision           11886 non-null  int64
#  13  pp_oneway_div       11886 non-null  object
#  14  pp_longdist_c       11886 non-null  int64
#  15  pp_otheragenc       11886 non-null  object
#  16  pp_yearofcurr       11886 non-null  int64
#  17  pp_lanemiles_       11886 non-null  float64
#  18  pp_lanemile_2       11886 non-null  float64
#  19  pp_centerline       11886 non-null  float64
#  20  pp_roadwayord       11886 non-null  float64
#  21  pp_shape_length     11886 non-null  float64
#  22  pp_source           11886 non-null  object
#  23  pp_ex_class         7426 non-null   float64
#  24  pp_pln_class        11864 non-null  float64
#  25  pp_mtc_facility_id  11886 non-null  object
#  26  source              11886 non-null  object
#  27  geometry            11886 non-null  geometry
# dtypes: float64(8), geometry(1), int64(4), object(15)
# memory usage: 2.5+ MB

# %%
oak.rename(columns={'pp_ex_class':'oak_ex_class','pp_pln_class':'oak_pln_class'},inplace=True)

# %%
oak.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 11886 entries, 0 to 11885
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   shstReferenceId     11886 non-null  object
#  1   shstGeometryId      11886 non-null  object
#  2   fromIntersectionId  11886 non-null  object
#  3   toIntersectionId    11886 non-null  object
#  4   pp_id               11886 non-null  int64
#  5   pp_shape_leng       11886 non-null  float64
#  6   pp_roadway          11886 non-null  object
#  7   pp_beginning        11886 non-null  object
#  8   pp_ending           11886 non-null  object
#  9   pp_proposedcl       11886 non-null  object
#  10  pp_existingcl       11886 non-null  object
#  11  pp_prioritypr       11886 non-null  object
#  12  pp_vision           11886 non-null  int64
#  13  pp_oneway_div       11886 non-null  object
#  14  pp_longdist_c       11886 non-null  int64
#  15  pp_otheragenc       11886 non-null  object
#  16  pp_yearofcurr       11886 non-null  int64
#  17  pp_lanemiles_       11886 non-null  float64
#  18  pp_lanemile_2       11886 non-null  float64
#  19  pp_centerline       11886 non-null  float64
#  20  pp_roadwayord       11886 non-null  float64
#  21  pp_shape_length     11886 non-null  float64
#  22  pp_source           11886 non-null  object
#  23  oak_ex_class        7426 non-null   float64
#  24  oak_pln_class       11864 non-null  float64
#  25  pp_mtc_facility_id  11886 non-null  object
#  26  source              11886 non-null  object
#  27  geometry            11886 non-null  geometry
# dtypes: float64(8), geometry(1), int64(4), object(15)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Test group by of duplicated records
#
# Group by shst id columns and bike class columns; retain mtc_facility id as list

# %%
#Check for duplicates
oak[oak[['shstReferenceId','shstGeometryId']].duplicated()]
# Out:
#                         shstReferenceId                    shstGeometryId  \
# 126    4986e051ce7ba7f469ec9305038f13a8  0ed42c1e507abb18e7b0fe523c61a713
# 129    ef34ebbec77f568bf60889a7ca424bcb  0ed42c1e507abb18e7b0fe523c61a713
# 275    85e34f2ce1303a96f91187a012222e3e  aa1c19c0bf002c10a8c5d17e55fb73db
# 290    467d0e2a11344d1e497e68cbcc04b8cc  aa1c19c0bf002c10a8c5d17e55fb73db
# 341    f6afcec45b5df6170b4243aa1d806123  ac384d4407cfcc9f5d3bb71efb2489d7
# ...                                 ...                               ...
# 11822  535ecf0a7e93948e3c5a81cfb1977b6f  5f0cb94eb5b86e876eb495c2d5654323
# 11828  1cf91f6443f7fa6f2e31ca91bda5f1b6  fe4cf6ef220e4e1138a45a75db51df61
# 11833  8645791fb2ad9e49452579d99f69a6a2  675519902c7809e1ec260a21808f0cc7
# 11835  ffdca4695812e7f9e62df0db30c07ae6  31a17f753fbc387eef874a5713cc7238
# 11868  291247587e7556dd997311d6716e6701  002b09ab7df1a4d1c7f2ba351e2a0e20
#
#                      fromIntersectionId                  toIntersectionId  \
# 126    3224ab7c86cb877d8de4c036c9e13d3e  af95bc2b171316ddb936a91c65d6bc5b
# 129    af95bc2b171316ddb936a91c65d6bc5b  3224ab7c86cb877d8de4c036c9e13d3e
# 275    9cd633e44806ad4fc4ddd008714cb2d6  bb371c559837e9050de08b6a34ada733
# 290    bb371c559837e9050de08b6a34ada733  9cd633e44806ad4fc4ddd008714cb2d6
# 341    3798afb343576b1a721acf7bb9ed6338  80e56a451d1a1afc93e0018a32983571
# ...                                 ...                               ...
# 11822  912c009b55ced41c077c88479fa2bd47  002a47375248af272aeb670cb741d674
# 11828  bfcaa6aad25b455ad425d1de9b4aeb88  05497cf4f5abe2881b6287c503f57ee5
# 11833  d04be73e50e562a5edcd39d85b533586  dce13e7961304828d1ce92035f639d62
# 11835  f7c84d3a0b4fd60e4d5008732ca7b83d  dcb4046d8effa067ed6c4f35e3509a1f
# 11868  1622bcd647e2f9ab966dd8a28c8bfcc2  9bb29f33e445b7b0054788e2ac1edf34
#
#        pp_id  pp_shape_leng            pp_roadway        pp_beginning  \
# 126      824      88.083853  Waterfront Trail #24
# 129      824      88.083853  Waterfront Trail #24
# 275      241    1219.421711         Foothill Blvd            41st Ave
# 290      241    1219.421711         Foothill Blvd            41st Ave
# 341      316    2937.129209    Lake Temescal Path            Broadway
# ...      ...            ...                   ...                 ...
# 11822    987    1495.301643        Hegenberger Rd  I-880 Ramps, south
# 11828    403    2262.190839                7th St           Fallon St
# 11833    403    2262.190839                7th St           Fallon St
# 11835   2166    4376.371522          Stanford Ave          Vallejo St
# 11868    288    2153.936902   Pleasant Valley Ave            Broadway
#
#                 pp_ending pp_proposedcl  ... pp_lanemile_2 pp_centerline  \
# 126                                   1  ...          0.03          0.02
# 129                                   1  ...          0.03          0.02
# 275              45th Ave            2B  ...          0.46          0.23
# 290              45th Ave            2B  ...          0.46          0.23
# 341          Broadway Ter             1  ...          1.11          0.56
# ...                   ...           ...  ...           ...           ...
# 11822  I-880 Ramps, north             4  ...          0.28          0.28
# 11828             5th Ave             4  ...          0.86          0.43
# 11833             5th Ave             4  ...          0.86          0.43
# 11835     Berkeley border             1  ...          1.66          0.83
# 11868        Piedmont Ave            2B  ...          0.82          0.41
#
#        pp_roadwayord pp_shape_length        pp_source oak_ex_class  \
# 126             28.0        0.000282  City of Oakland          1.0
# 129             28.0        0.000282  City of Oakland          1.0
# 275             13.0        0.003826  City of Oakland          3.0
# 290             13.0        0.003826  City of Oakland          3.0
# 341              0.0        0.008739  City of Oakland          1.0
# ...              ...             ...              ...          ...
# 11822            4.4        0.004113  City of Oakland          NaN
# 11828           12.0        0.007432  City of Oakland          2.0
# 11833           12.0        0.007432  City of Oakland          2.0
# 11835            0.0        0.014359  City of Oakland          NaN
# 11868            1.0        0.006683  City of Oakland          NaN
#
#        oak_pln_class                    pp_mtc_facility_id  \
# 126              1.0  c719c482-2e22-4123-a3ed-f86744b24800
# 129              1.0  c719c482-2e22-4123-a3ed-f86744b24800
# 275              2.0  310fb8a8-7836-4824-8e4d-0fc3da5a181a
# 290              2.0  310fb8a8-7836-4824-8e4d-0fc3da5a181a
# 341              1.0  b03204cc-89ab-4d5e-8eae-0a2da4fd9a82
# ...              ...                                   ...
# 11822            4.0  8ff3177d-47e2-4307-9e2f-ceb7a756397c
# 11828            4.0  93be08aa-d774-4485-885a-e94770f95906
# 11833            4.0  93be08aa-d774-4485-885a-e94770f95906
# 11835            1.0  2952f0c6-55ae-4068-93cc-de8cba507393
# 11868            2.0  1c2ddab3-2773-4076-aa2f-a8c1ad4c9987
#
#                                                   source  \
# 126    1_bike_rules\oakland_bike_network_epsg4326.out...
# 129    1_bike_rules\oakland_bike_network_epsg4326.out...
# 275    1_bike_rules\oakland_bike_network_epsg4326.out...
# 290    1_bike_rules\oakland_bike_network_epsg4326.out...
# 341    1_bike_rules\oakland_bike_network_epsg4326.out...
# ...                                                  ...
# 11822  2_car_rules\oakland_bike_network_epsg4326.out....
# 11828  2_car_rules\oakland_bike_network_epsg4326.out....
# 11833  2_car_rules\oakland_bike_network_epsg4326.out....
# 11835  2_car_rules\oakland_bike_network_epsg4326.out....
# 11868  2_car_rules\oakland_bike_network_epsg4326.out....
#
#                                                 geometry
# 126    LINESTRING (-122.23269 37.77072, -122.23268 37...
# 129    LINESTRING (-122.23255 37.77069, -122.23266 37...
# 275    LINESTRING (-122.21387 37.77650, -122.21366 37...
# 290    LINESTRING (-122.21366 37.77632, -122.21387 37...
# 341    LINESTRING (-122.23086 37.84867, -122.23086 37...
# ...                                                  ...
# 11822  LINESTRING (-122.19665 37.73944, -122.19666 37...
# 11828  LINESTRING (-122.26104 37.79351, -122.26072 37...
# 11833  LINESTRING (-122.25815 37.79269, -122.25804 37...
# 11835  LINESTRING (-122.27308 37.84612, -122.27311 37...
# 11868  LINESTRING (-122.24813 37.83089, -122.24743 37...
#
# [1115 rows x 28 columns]

# %%
#Dissolve by shared streets id columns and bike class columns
sub_cols = ['shstReferenceId','shstGeometryId','oak_ex_class','oak_pln_class','pp_mtc_facility_id']
diss_cols = ['shstReferenceId','shstGeometryId','oak_ex_class','oak_pln_class']
oak_group_test = (oak[sub_cols].
                  groupby(diss_cols)['pp_mtc_facility_id']
                  .apply(lambda x: list(x)).reset_index())

# %%
oak_group_test['fac_diss_count'] = oak_group_test['pp_mtc_facility_id'].apply(lambda x: len(x))

# %%
oak_group_test[['pp_mtc_facility_id','fac_diss_count']][oak_group_test['fac_diss_count'] > 1]
# Out:
#                                      pp_mtc_facility_id  fac_diss_count
# 26    [79ebf29a-0a9e-47c4-ac4f-efc2ffc8e09a, 09e7b81...               2
# 40    [be266bc9-9aa1-4a14-9938-1c0131378447, 4a359de...               2
# 42    [293e96ec-1bd6-4d1d-995b-09be9642a2fe, 6f77dad...               2
# 61    [93ea24c5-79c8-401c-b5a4-0f824bb0c3f5, 75f01fe...               2
# 98    [f02c63cb-ccc8-4c85-a7a6-ac129e52b2ca, 976a5d1...               2
# ...                                                 ...             ...
# 6920  [abeff34b-b6ff-4602-a853-bacd900a6986, 8d7ba71...               3
# 6927  [aa43a38a-4df6-443f-accf-abc3e2cfe4b9, 9003fcb...               2
# 6967  [291a43c0-928c-4e12-8e1f-8e6e2539c296, 63a86e6...               2
# 6981  [207b5095-1cbc-46cf-90fe-da6bd6db5d51, 6a09c0a...               2
# 6982  [3fb258d1-3afe-4370-b27e-01e3da3fbc55, ac422d2...               2
#
# [391 rows x 2 columns]

# %%
#Duplicates still exist. Why? 
oak_group_test[oak_group_test[['shstReferenceId','shstGeometryId']].duplicated()]
# Out:
#                        shstReferenceId                    shstGeometryId  \
# 17    010ffd02f550aae59c98b93fe7854f73  7a053e6a1568a6a6b737c39be4beaf95
# 21    014104033f46bb3af63ef4557164f2f5  daba5f1ad45122a1a9a43d7ef93280ad
# 44    01b88bef700aa0469ae55eb26c763520  644eee67d7b3991f2266d2eddb01a362
# 52    024eab1874990bad0895731749837573  77d057d0c3edef3a1699a1ff66b29d0b
# 57    025983e01cc43440216f362e8217a814  b3d699e92d43d9ac1fb4834a8dc6f724
# ...                                ...                               ...
# 6893  fc71bf81f1a57c87a7c6da4a83fc3429  d7fed0d482024d6b56c3ca7de0d52bee
# 6924  fdb9d0bb592cb893419b532e6f5c1339  282444aeb5a9a39e82eb78131ca1d5f1
# 6933  fe21159ca7ec5a3425b708394005c8ac  7a053e6a1568a6a6b737c39be4beaf95
# 6949  fed2fe70c18e1072b4bf07541791f2ad  4d44342c592ef89fa089a9d661217466
# 6988  fff0a75e3b02f0582298fab01d144875  170d565550f619683aa2b2976955b7ec
#
#       oak_ex_class  oak_pln_class                      pp_mtc_facility_id  \
# 17             3.0            2.0  [491eec43-b389-49fd-9e05-66e53504ba8d]
# 21             2.0            4.0  [4a9e55a2-3319-4d7a-9bcd-70d76c7640ea]
# 44             2.0            1.0  [5c690a89-7322-4743-a34e-827dfb799d50]
# 52             3.0            3.0  [2f638f3e-3775-40ec-bb72-3118307719ab]
# 57             3.0            2.0  [e5f8876d-e0dc-47cc-bd90-883b6649fa19]
# ...            ...            ...                                     ...
# 6893           3.0            2.0  [4c3a0957-d5fa-4261-a115-de709252e8cf]
# 6924           3.0            2.0  [013997bc-bd34-40ac-b17f-06d59b6749d7]
# 6933           3.0            2.0  [491eec43-b389-49fd-9e05-66e53504ba8d]
# 6949           3.0            2.0  [7f5f4a9b-9386-4ac6-ac9b-009bb4f7b69d]
# 6988           3.0            2.0  [e7939d0f-3f7e-4ef9-8ea1-0694c226f890]
#
#       fac_diss_count
# 17                 1
# 21                 1
# 44                 1
# 52                 1
# 57                 1
# ...              ...
# 6893               1
# 6924               1
# 6933               1
# 6949               1
# 6988               1
#
# [227 rows x 6 columns]

# %%
#Different Classes 
oak_group_test[(oak_group_test['shstReferenceId'] == '010ffd02f550aae59c98b93fe7854f73') & 
               (oak_group_test['shstGeometryId'] == '7a053e6a1568a6a6b737c39be4beaf95')]
# Out:
#                      shstReferenceId                    shstGeometryId  \
# 16  010ffd02f550aae59c98b93fe7854f73  7a053e6a1568a6a6b737c39be4beaf95
# 17  010ffd02f550aae59c98b93fe7854f73  7a053e6a1568a6a6b737c39be4beaf95
#
#     oak_ex_class  oak_pln_class                      pp_mtc_facility_id  \
# 16           2.0            2.0  [435b4202-c56a-4697-914a-4c367c1aec28]
# 17           3.0            2.0  [491eec43-b389-49fd-9e05-66e53504ba8d]
#
#     fac_diss_count
# 16               1
# 17               1
