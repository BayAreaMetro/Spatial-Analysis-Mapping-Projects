# %%
from pathlib import Path
import pandas as pd
import geopandas as gpd
from mtcpy.aws import pull_df_from_redshift_sql, pull_geotable_redshift
# Out:
# Info: Found credentials at: /Users/jcroff/Library/CloudStorage/Box-Box/dvutils-creds-jcroff.json

# %%
# set workign directory 
work_dir = Path("/Users/jcroff/Library/CloudStorage/Box-Box/DSA Projects/Spatial Analysis and Mapping/Wildfire Risk Analysis/Data Outputs")

# %% [markdown]
# # pull data from redshift

# %%
req_cols = [
    "geoid",
    # "zoning_type", - out of scope
    # "zoning_subtype", - out of scope
    "structno",
    "yearbuilt",
    "numstories",
    "numunits",
    # "numrooms", - out of scope
    # "structstyle", - available in premium but not ingested into redshift
    # "improvval", - out of scope
    # "landval", - out of scope
    # "parval", - out of scope
    "saleprice",
    "scity",
    "county",
    "szip",
    "lat",
    "lon",
    "fema_flood_zone",
    # "fema_nri_risk_rating", - available in premium but not ingested into redshift
    # "qoz", - avialable in premium but not ingested into redshift
    # "census_tract", - out of scope
    # "census_block", - out of scope
    # "sourceurl", - available in premium but not ingested into redshift
    # "recrdareano", - available in premium but not ingested into redshift
    "ll_gisacre",
    "ll_gissqft",
    "ll_bldg_footprint_sqft",
    "ll_uuid",
    "ll_stack_uuid",
    "ll_bldg_count",
    "lbcs_structure_desc",
    # "housing_affordability_index", - available in premium but not ingested into redshift
    # "population_density", - available in premium but not ingested into redshift
    # "population_growth_past_5_years", - available in premium but not ingested into redshift
    # "population_growth_next_5_years", - available in premium but not ingested into redshift
    # "housing_growth_past_5_years", - available in premium but not ingested into redshift
    # "housing_growth_next_5_years", - available in premium but not ingested into redshift
    # "median_household_income", - available in premium but not ingested into redshift
    # "transmission_line_distance", - available in premium but not ingested into redshift
]
sql_cols = ", ".join(req_cols)
sql = f"SELECT {sql_cols} FROM regrid_v25.parcel_source_tbl_v25" 
df = pull_df_from_redshift_sql(sql_statement=sql)
# Out:
# took 1.3119 minutes

# %%
# convert numeric columns to numeric
numeric_cols = [
    "structno",
    "yearbuilt",
    "numstories",
    "numunits",
]
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col])

# %%
df["numunits"].isna().mean()

# overall, .80 of the parcels is missing numunits
# Out:
# 0.8002539159719686

# %%
# get a count of records where structno is equal to or greater than 1
df[df["structno"] > 0].shape[0]
# Out:
# 159013

# %%
# get a count of records where ll_bldg_count is equal to or greater than 1
df[df["ll_bldg_count"] > 0].shape[0]
# Out:
# 2168498

# %%
# get a count of records where numunits is not null but structno is null
df[(df["numunits"].notnull()) & (df["structno"].isnull())].shape[0]
# Out:
# 311022

# %%
# get a count of records where numunits is not null but ll_bldg_count is null
df[(df["numunits"].notnull()) & (df["ll_bldg_count"].isnull())].shape[0]
# Out:
# 0

# %%
# get a summary of non-null numunits by lbcs_structure_desc
grouped = df.groupby("lbcs_structure_desc")["numunits"].agg(
    count_non_null_units="count",  # non-null values
    total_number_structures="size",  # total number of rows in group
    missing_units=lambda x: x.isna().sum(),  # number of missing
    missing_pct_units=lambda x: x.isna().mean() * 100,  # percent missing
)
grouped
# Out:
#                                           count_non_null_units  \
# lbcs_structure_desc
# Air and space transportation facility                        0
# Airport terminal                                             0
# Assembly and construction-type plants                        0
# Attached units                                           10858
# Automobile parking facilities                                4
# ...                                                        ...
# Utility and other nonbuilding structures                     0
# Warehouse discount store building                            1
# Warehouse or storage facility                              106
# Water transportation or marine related                       0
# Water-supply-related facility                                0
#
#                                           total_number_structures  \
# lbcs_structure_desc
# Air and space transportation facility                          20
# Airport terminal                                               19
# Assembly and construction-type plants                         216
# Attached units                                              10876
# Automobile parking facilities                                1532
# ...                                                           ...
# Utility and other nonbuilding structures                     1075
# Warehouse discount store building                              10
# Warehouse or storage facility                                6694
# Water transportation or marine related                          9
# Water-supply-related facility                                 485
#
#                                           missing_units  missing_pct_units
# lbcs_structure_desc
# Air and space transportation facility                20         100.000000
# Airport terminal                                     19         100.000000
# Assembly and construction-type plants               216         100.000000
# Attached units                                       18           0.165502
# Automobile parking facilities                      1528          99.738903
# ...                                                 ...                ...
# Utility and other nonbuilding structures           1075         100.000000
# Warehouse discount store building                     9          90.000000
# Warehouse or storage facility                      6588          98.416492
# Water transportation or marine related                9         100.000000
# Water-supply-related facility                       485         100.000000
#
# [74 rows x 4 columns]

# %%
grouped.sort_values(by='missing_pct_units', ascending=True).reset_index().to_csv(
    work_dir / "missing_numunits_by_structure_type.csv",
    index=False
)

# %%
df.lbcs_structure_desc.unique()
# Out:
# array(['Residential buildings', 'Unclassified', 'Single-family buildings',
#        'Water-supply-related facility',
#        'Railroads, including monorails, etc.', 'Office or bank building',
#        'Manufactured housing', 'Highways and roads',
#        'Multifamily structures',
#        'Utility and other nonbuilding structures',
#        'Store or shop building', 'Department store building',
#        'Hotels, motels, and tourist courts',
#        'Sheds, farm buildings, or agricultural facilities',
#        'Industrial buildings and structures',
#        'Multifamily structures: Two Units',
#        'Office or store building with residence on top',
#        'Multifamily structures: Four Units', 'Townhouses',
#        'Medical facility', 'Public assembly structures',
#        'Warehouse or storage facility',
#        'Light industrial structures and facilities',
#        'Commercial buildings and other specialized structures',
#        'School or university buildings',
#        'Automobile repair and service structures', 'Greenhouses',
#        'Automobile parking facilities', 'Duplex structures',
#        'Restaurant building',
#        'Churches, synagogues, temples, mosques, etc.',
#        'Multifamily structures: Three Units', 'Gasoline station',
#        'Attached units',
#        'Multifamily structures: Other specialized residential structures',
#        'Laboratory or specialized industrial facility',
#        'Mill-type factory structures',
#        'Institutional or community facilities',
#        'Cemetery, monument, tombstone, or mausoleum',
#        'Linear or network feature',
#        'Neighborhood center (convenience with one or more anchors)',
#        'College or university facility',
#        'Assembly and construction-type plants', 'Livestock facility',
#        'Transportation-related facilities', 'Fire and rescue station',
#        'Malls, shopping centers, or collection of shops',
#        'Mini-warehouse', 'Landfill facility', 'Hospital building',
#        'Detached units', 'Air and space transportation facility',
#        'Indoor games facility', 'Medical clinic building',
#        'Other community structures',
#        'Process plants (metals, chemicals, etc.)',
#        'Heavy industrial structures and facilities', 'Airport terminal',
#        'Water transportation or marine related',
#        'Community center (general merchandise with two or more anchors)',
#        'Grain silos and other storage structure for grains and agricultural products',
#        'Funeral homes and cremation facilities',
#        'Temporary structures, tents, etc. for shelter',
#        'Power generation plants', 'Theater',
#        'Warehouse discount store building', 'Gas and fuel lines',
#        'Communication towers', 'Refrigerated warehouse or cold storage',
#        'Regional center (enclosed mall with two or more anchors)',
#        'Cattle facility', 'Convenience stores or centers',
#        'Specialized military structures', 'Sports stadium or arena'],
#       dtype=object)

# %%
# look at single-family building missing numunits
df.query("lbcs_structure_desc == 'Single-family buildings'")
# Out:
#          geoid  structno  yearbuilt  numstories  numunits  saleprice  \
# 131      06085       NaN     2018.0         NaN       NaN        NaN
# 132      06085       NaN     2018.0         NaN       NaN        NaN
# 133      06085       NaN     2018.0         NaN       NaN        NaN
# 134      06085       NaN     2018.0         NaN       NaN        NaN
# 135      06085       NaN     2018.0         NaN       NaN        NaN
# ...        ...       ...        ...         ...       ...        ...
# 2324330  06097       1.0     1927.0         1.0       1.0   185000.0
# 2324382  06097       1.0     1964.0         1.0       1.0   650000.0
# 2324383  06097       1.0     1964.0         1.0       1.0   585000.0
# 2324384  06097       1.0     1963.0         1.0       1.0   600000.0
# 2324385  06097       1.0     1965.0         1.0       1.0   519900.0
#
#               scity       county        szip        lat         lon  \
# 131          Gilroy  Santa Clara  95020-4183  37.018880 -121.586218
# 132          Gilroy  Santa Clara  95020-4183  37.018877 -121.586395
# 133          Gilroy  Santa Clara  95020-4183  37.018917 -121.584843
# 134          Gilroy  Santa Clara  95020-4183  37.018919 -121.585000
# 135          Gilroy  Santa Clara  95020-4183  37.018921 -121.585157
# ...             ...          ...         ...        ...         ...
# 2324330  Santa Rosa       Sonoma  95407-7757  38.386830 -122.733277
# 2324382  Santa Rosa       Sonoma  95409-3512  38.469401 -122.662494
# 2324383  Santa Rosa       Sonoma  95409-3561  38.469394 -122.662788
# 2324384  Santa Rosa       Sonoma  95409-3561  38.469345 -122.663000
# 2324385  Santa Rosa       Sonoma  95409-3560  38.468961 -122.662749
#
#         fema_flood_zone  ll_gisacre  ll_gissqft  ll_bldg_footprint_sqft  \
# 131                   X        0.08      3342.0                  1918.0
# 132                   X        0.09      4111.0                  2150.0
# 133                   X        0.09      3884.0                  2499.0
# 134                   X        0.09      3886.0                  2129.0
# 135                   X        0.09      3890.0                  2245.0
# ...                 ...         ...         ...                     ...
# 2324330               X        0.49     21187.0                  4819.0
# 2324382               X        0.16      7153.0                  2294.0
# 2324383               X        0.16      7168.0                  2746.0
# 2324384               X        0.17      7317.0                  2913.0
# 2324385               X        0.14      6009.0                  2388.0
#
#                                       ll_uuid ll_stack_uuid  ll_bldg_count  \
# 131      08c3a857-86eb-4d7a-87c6-e59dc463bc46          None              1
# 132      1e97c378-390b-4164-a257-dbb1c88a8b52          None              1
# 133      7f5f3f7f-a5c6-4f15-9c00-6ea78c9b1875          None              1
# 134      92cac6f9-addf-4cde-a65b-0bf26d352694          None              1
# 135      db5df4de-4305-47a3-affc-671144920fae          None              1
# ...                                       ...           ...            ...
# 2324330  c5222228-2a2f-42dd-b2ed-dc52225b98c6          None              5
# 2324382  f1cf800b-a81d-45fe-817c-076b9c1bd0b3          None              1
# 2324383  bb826a59-c0ef-4dc7-ad05-6178dbf5f01d          None              1
# 2324384  9fdfaa91-f612-4bae-b795-3cfa54887ee1          None              1
# 2324385  e0e220bf-9682-429d-ba52-54b3ab4474f4          None              1
#
#              lbcs_structure_desc
# 131      Single-family buildings
# 132      Single-family buildings
# 133      Single-family buildings
# 134      Single-family buildings
# 135      Single-family buildings
# ...                          ...
# 2324330  Single-family buildings
# 2324382  Single-family buildings
# 2324383  Single-family buildings
# 2324384  Single-family buildings
# 2324385  Single-family buildings
#
# [1129744 rows x 19 columns]
