# %%
import os
import sys
import getpass

user = getpass.getuser()

DVUTILS_LOCAL_CLONE_PATH = f"/Users/{user}/Documents/GitHub/dvutils/dvutils"
sys.path.insert(0, DVUTILS_LOCAL_CLONE_PATH)
from census import *

# %%
 # get census api key
api_key = os.environ.get("CENSUS_API_KEY")

# %%
# test pulling acs 5 year data at the block group level
bg_df = pull_acs_data(
    census_api_key=api_key, acs_year=2022, table_id="B01001", geography_level="Block Group"
)

# %%
bg_df.head(5)
# Out:
#    B01001_001E  B01001_002E  B01001_003E  B01001_004E  B01001_005E  \
# 0         1010          468            0           39           12
# 1         2114         1098           82          108           34
# 2         2378          840           23           70           88
# 3         2682         1296           44           11          137
# 4          757          451           45           17            0
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  ...  \
# 0           46           56            0            0            0  ...
# 1           48           87           19           40           28  ...
# 2           16            0            0           19            0  ...
# 3           35          110           80            0           69  ...
# 4           49           27            0            0            0  ...
#
#    B01001_042E  B01001_043E  B01001_044E  B01001_045E  B01001_046E  \
# ...

# %%
# test pulling acs 5 year data at the tract level
tract_df = pull_acs_data(
    census_api_key=api_key, acs_year=2022, table_id="B01001", geography_level="Tract"
)

# %%
tract_df.head(5)
# Out:
#    B01001_001E  B01001_002E  B01001_003E  B01001_004E  B01001_005E  \
# 0         2744         1258           57           47           91
# 1         4248         2332          244          129           80
# 2         7425         3538          358          245          186
# 3         5947         3038           56           89          164
# 4         4724         2592            0          160          154
#
#    B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  ...  \
# 0           45           13           53           42           12  ...
# 1           23           21            0            9           49  ...
# 2          234          202           24          136            0  ...
# 3           77           71           26            8           49  ...
# 4           96           41           22          204           97  ...
#
#    B01001_042E  B01001_043E  B01001_044E  B01001_045E  B01001_046E  \
# ...

# %% [markdown]
# # test pulling acs 5 year data at the block group level for specific variables
# bg_df = pull_acs_5_year_est_data(
#     census_api_key=api_key,
#     acs_year=2022,
#     select_table_vars=["B01001_001E", "B01001_002E"],
#     geography_level="Block Group",
# )

# %%
bg_df
# Out:
#       B01001_001E  B01001_002E  B01001_003E  B01001_004E  B01001_005E  \
# 0            1010          468            0           39           12
# 1            2114         1098           82          108           34
# 2            2378          840           23           70           88
# 3            2682         1296           44           11          137
# 4             757          451           45           17            0
# ...           ...          ...          ...          ...          ...
# 5182          702          294            0           37           37
# 5183         1098          525           11           71           31
# 5184         1125          579           45           34           35
# 5185          818          422           34           33            0
# 5186         1189          512           33           78           25
#
#       B01001_006E  B01001_007E  B01001_008E  B01001_009E  B01001_010E  ...  \
# ...

# %%
# test pulling acs 5 year data at the tract level for specific variables
tract_df = pull_acs_data(
    census_api_key=api_key,
    acs_year=2022,
    select_table_vars=["B01001_001E", "B01001_002E"],
    geography_level="Tract",
)

# %%
tract_df.head(5)
# Out:
#    B01001_001E  B01001_002E fipco  tract_geoid
# 0         3269         1621   001  06001400100
# 1         2147         1075   001  06001400200
# 2         5619         2801   001  06001400300
# 3         4278         1926   001  06001400400
# 4         3949         1870   001  06001400500
